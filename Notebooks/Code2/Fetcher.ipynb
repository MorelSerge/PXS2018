# %%
import utils
import json
from mapboxfetcher import MapBoxFetcher
import numpy as np
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import PIL
import pickle
from treemodel import TreeModel
import imagefunctions
import os.path
from shapely.geometry import Polygon
from keras.models import load_model
# %load_ext autoreload
# %autoreload 2
# Out:
# c:\program files\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nn_model = load_model('NNModelOne128One256One128Layer.h5')
# with open('TrainedModelManualZoom16.p', 'rb') as f:
#     ada_model = pickle.load(f)
tree_model = TreeModel(nn_model)

# %%
def squareCoordinatesToGeoJSON(coordinates):
    if isinstance(coordinates, np.ndarray):
        coordinates = coordinates.tolist()
    feature = {
        'type': 'Feature',
        'properties': {},
        'geometry': {
            'type': 'Polygon',
            'coordinates': [[
                coordinates[0][::-1],
                coordinates[1][::-1],
                coordinates[2][::-1],
                coordinates[3][::-1],
                coordinates[0][::-1]
            ]]
        }
    }
    return json.dumps(feature)
def polygonFromSquareCoordinates(coordinates):
    return Polygon([(c[1], c[0]) for c in coordinates])
def getTileCorners(x, y, zoom):
    ul = utils.num2deg(x, y, zoom)
    ur = utils.num2deg(x+1, y, zoom)
    lr = utils.num2deg(x+1, y+1, zoom)
    ll = utils.num2deg(x, y+1, zoom)
    return [ul, ur, lr, ll]
def getTileGeoJSON(x, y, zoom):
    ul, ur, lr, ll = getTileCorners(x, y, zoom)
    return squareCoordinatesToGeoJSON([ul, ur, lr, ll])
def splitTile(x, y, zoom, splits = 8):
    ul, ur, lr, ll = getTileCorners(x, y, zoom)
    lat_diff = (ul[0] - ll[0]) / splits
    long_diff = (ur[1] - ul[1]) / splits
    out = np.ndarray((splits, splits, 4, 2))
    for i in range(splits):
        for j in range(splits):
            out[i,j,:,:] = [
                [ul[0] - i*lat_diff, ul[1] + j*long_diff],
                [ul[0] - i*lat_diff, ul[1] + (j+1)*long_diff],
                [ul[0] - (i+1)*lat_diff, ul[1] + (j+1)*long_diff],
                [ul[0] - (i+1)*lat_diff, ul[1] + j*long_diff],
            ]
    return out

# %%
geojson = json.load(open('Vaud.geojson'))
polygon = utils.polygon_union(geojson['features'])
bounds = polygon.bounds
zoom = 16

# %%
lat, lon = bounds[3], bounds[0]
start_numx, start_numy = utils.deg2num(lat, lon, zoom)
numx, numy = start_numx, start_numy

tile_count = 0
total_tile_count = 0
tile_x_count = 0
tile_y_count = 0
fetcher = MapBoxFetcher()

while lat >= bounds[1]:
    while lon <= bounds[2]:
        c_poly = polygonFromSquareCoordinates(getTileCorners(numx, numy, zoom))
        if polygon.intersects(c_poly):
            total_tile_count += 1
        tile_count += 1

        numx += 1
        lon = utils.num2deg(numx, numy, zoom)[1]
    lon = bounds[0]
    numx = start_numx
    numy += 1
    tile_y_count += 1
    lat = utils.num2deg(numx, numy, zoom)[0]
tile_x_count = tile_count // tile_y_count
    
print('Polygon contains {} tiles at zoom level {} with tile resolution {}x{}'.format(
    total_tile_count,
    zoom,
    tile_y_count,
    tile_x_count
))
# Out:
# Polygon contains 19055 tiles at zoom level 16 with tile resolution 213x217

# %%
zoom = 16
lat, lon = bounds[3], bounds[0]
start_numx, start_numy = utils.deg2num(lat, lon, zoom)
numx, numy = start_numx, start_numy

fetcher = MapBoxFetcher()

data = []

while lat >= bounds[1]:
    read_numxs = []
    added = False
    if os.path.isfile('Data/Predictions-Y{}.p'.format(numy)):
        with open('Data/Predictions-Y{}.p'.format(numy), 'rb') as f:
            data = pickle.load(f)
            for c in data:
                read_numxs.append(c['x'])
    while lon <= bounds[2]:
        if numx in read_numxs:
            numx += 1
            lon = utils.num2deg(numx, numy, zoom)[1]
            continue
        c_poly = polygonFromSquareCoordinates(getTileCorners(numx, numy, zoom))
        if polygon.intersects(c_poly):
            sat_img = fetcher.satellite(numx, numy, zoom, hq=True)
            data.append({
                'x': numx,
                'y': numy,
                'pred': imagefunctions.threshold(imagefunctions.filter(tree_model.predict_proba(sat_img.array())))
            })
            added = True
        numx += 1
        lon = utils.num2deg(numx, numy, zoom)[1]
    if added:
        pickle.dump(data, open('Data/Predictions-Y{}.p'.format(numy), 'wb'))
    print('Fetched and predicted satellite row {} with {} images along X'.format(numy, len(data)))
    data = []
        
    lon = bounds[0]
    numx = start_numx
    numy += 1
    lat = utils.num2deg(numx, numy, zoom)[0]
# Out:
# Fetched and predicted satellite row 23054 with 5 images along X
# Fetched and predicted satellite row 23055 with 9 images along X
# Fetched and predicted satellite row 23056 with 15 images along X
# Fetched and predicted satellite row 23057 with 17 images along X
# Fetched and predicted satellite row 23058 with 19 images along X
# Fetched and predicted satellite row 23059 with 20 images along X
# Fetched and predicted satellite row 23060 with 22 images along X
# Fetched and predicted satellite row 23061 with 23 images along X
# Fetched and predicted satellite row 23062 with 25 images along X
# Fetched and predicted satellite row 23063 with 25 images along X
# Fetched and predicted satellite row 23064 with 25 images along X
# Fetched and predicted satellite row 23065 with 24 images along X
# Fetched and predicted satellite row 23066 with 23 images along X
# Fetched and predicted satellite row 23067 with 24 images along X
# Fetched and predicted satellite row 23068 with 26 images along X
# Fetched and predicted satellite row 23069 with 28 images along X
# Fetched and predicted satellite row 23070 with 31 images along X
# Fetched and predicted satellite row 23071 with 36 images along X
# Fetched and predicted satellite row 23072 with 36 images along X
# Fetched and predicted satellite row 23073 with 40 images along X
# Fetched and predicted satellite row 23074 with 46 images along X
# Fetched and predicted satellite row 23075 with 48 images along X
# Fetched and predicted satellite row 23076 with 49 images along X
# Fetched and predicted satellite row 23077 with 48 images along X
# Fetched and predicted satellite row 23078 with 49 images along X
# Fetched and predicted satellite row 23079 with 46 images along X
# Fetched and predicted satellite row 23080 with 51 images along X
# Fetched and predicted satellite row 23081 with 58 images along X
# Fetched and predicted satellite row 23082 with 61 images along X
# Fetched and predicted satellite row 23083 with 62 images along X
# Fetched and predicted satellite row 23084 with 61 images along X
# Fetched and predicted satellite row 23085 with 65 images along X
# Fetched and predicted satellite row 23086 with 69 images along X
# Fetched and predicted satellite row 23087 with 68 images along X
# Fetched and predicted satellite row 23088 with 63 images along X
# Fetched and predicted satellite row 23089 with 68 images along X
# Fetched and predicted satellite row 23090 with 73 images along X
# Fetched and predicted satellite row 23091 with 77 images along X
# Fetched and predicted satellite row 23092 with 74 images along X
# Fetched and predicted satellite row 23093 with 75 images along X
# Fetched and predicted satellite row 23094 with 74 images along X
# Fetched and predicted satellite row 23095 with 75 images along X
# Fetched and predicted satellite row 23096 with 73 images along X
# Fetched and predicted satellite row 23097 with 74 images along X
# Fetched and predicted satellite row 23098 with 71 images along X
# Fetched and predicted satellite row 23099 with 70 images along X
# Fetched and predicted satellite row 23100 with 72 images along X
# Fetched and predicted satellite row 23101 with 74 images along X
# Fetched and predicted satellite row 23102 with 73 images along X
# Fetched and predicted satellite row 23103 with 76 images along X
# Fetched and predicted satellite row 23104 with 74 images along X
# Fetched and predicted satellite row 23105 with 71 images along X
# Fetched and predicted satellite row 23106 with 70 images along X
# Fetched and predicted satellite row 23107 with 74 images along X
# Fetched and predicted satellite row 23108 with 82 images along X
# Fetched and predicted satellite row 23109 with 87 images along X
# Fetched and predicted satellite row 23110 with 89 images along X
# Fetched and predicted satellite row 23111 with 90 images along X
# Fetched and predicted satellite row 23112 with 89 images along X
# Fetched and predicted satellite row 23113 with 90 images along X
# Fetched and predicted satellite row 23114 with 88 images along X
# Fetched and predicted satellite row 23115 with 85 images along X
# Fetched and predicted satellite row 23116 with 90 images along X
# Fetched and predicted satellite row 23117 with 92 images along X
# Fetched and predicted satellite row 23118 with 91 images along X
# Fetched and predicted satellite row 23119 with 90 images along X
# Fetched and predicted satellite row 23120 with 88 images along X
# Fetched and predicted satellite row 23121 with 93 images along X
# Fetched and predicted satellite row 23122 with 96 images along X
# Fetched and predicted satellite row 23123 with 101 images along X
# Fetched and predicted satellite row 23124 with 103 images along X
# Fetched and predicted satellite row 23125 with 104 images along X
# Fetched and predicted satellite row 23126 with 104 images along X
# Fetched and predicted satellite row 23127 with 103 images along X
# Fetched and predicted satellite row 23128 with 105 images along X
# Fetched and predicted satellite row 23129 with 107 images along X
# Fetched and predicted satellite row 23130 with 108 images along X
# Fetched and predicted satellite row 23131 with 109 images along X
# Fetched and predicted satellite row 23132 with 112 images along X
# Fetched and predicted satellite row 23133 with 112 images along X
# Fetched and predicted satellite row 23134 with 112 images along X
# Fetched and predicted satellite row 23135 with 110 images along X
# Fetched and predicted satellite row 23136 with 110 images along X
# Fetched and predicted satellite row 23137 with 112 images along X
# Fetched and predicted satellite row 23138 with 113 images along X
# Fetched and predicted satellite row 23139 with 114 images along X
# Fetched and predicted satellite row 23140 with 115 images along X
# Fetched and predicted satellite row 23141 with 115 images along X
# Fetched and predicted satellite row 23142 with 112 images along X
# Fetched and predicted satellite row 23143 with 109 images along X
# Fetched and predicted satellite row 23144 with 110 images along X
# Fetched and predicted satellite row 23145 with 108 images along X
# Fetched and predicted satellite row 23146 with 108 images along X
# Fetched and predicted satellite row 23147 with 110 images along X
# Fetched and predicted satellite row 23148 with 110 images along X
# Fetched and predicted satellite row 23149 with 112 images along X
# Fetched and predicted satellite row 23150 with 114 images along X
# Fetched and predicted satellite row 23151 with 115 images along X
# Fetched and predicted satellite row 23152 with 115 images along X
# Fetched and predicted satellite row 23153 with 116 images along X
# Fetched and predicted satellite row 23154 with 118 images along X
# Fetched and predicted satellite row 23155 with 119 images along X
# Fetched and predicted satellite row 23156 with 121 images along X
# Fetched and predicted satellite row 23157 with 121 images along X
# Fetched and predicted satellite row 23158 with 123 images along X
# Fetched and predicted satellite row 23159 with 124 images along X
# Fetched and predicted satellite row 23160 with 125 images along X
# Fetched and predicted satellite row 23161 with 130 images along X
# Fetched and predicted satellite row 23162 with 137 images along X
# Fetched and predicted satellite row 23163 with 139 images along X
# Fetched and predicted satellite row 23164 with 140 images along X
# Fetched and predicted satellite row 23165 with 143 images along X
# Fetched and predicted satellite row 23166 with 142 images along X
# Fetched and predicted satellite row 23167 with 141 images along X
# Fetched and predicted satellite row 23168 with 138 images along X
# Fetched and predicted satellite row 23169 with 138 images along X
# Fetched and predicted satellite row 23170 with 138 images along X
# Fetched and predicted satellite row 23171 with 140 images along X
# Fetched and predicted satellite row 23172 with 142 images along X
# Fetched and predicted satellite row 23173 with 145 images along X
# Fetched and predicted satellite row 23174 with 140 images along X
# Fetched and predicted satellite row 23175 with 144 images along X
# Fetched and predicted satellite row 23176 with 145 images along X
# Fetched and predicted satellite row 23177 with 146 images along X
# Fetched and predicted satellite row 23178 with 151 images along X
# Fetched and predicted satellite row 23179 with 154 images along X
# Fetched and predicted satellite row 23180 with 161 images along X
# Fetched and predicted satellite row 23181 with 164 images along X
# Fetched and predicted satellite row 23182 with 170 images along X
# Fetched and predicted satellite row 23183 with 176 images along X
# Fetched and predicted satellite row 23184 with 180 images along X
# Fetched and predicted satellite row 23185 with 185 images along X
# Fetched and predicted satellite row 23186 with 193 images along X
# Fetched and predicted satellite row 23187 with 193 images along X
# Fetched and predicted satellite row 23188 with 194 images along X
# Fetched and predicted satellite row 23189 with 198 images along X
# Fetched and predicted satellite row 23190 with 200 images along X
# Fetched and predicted satellite row 23191 with 203 images along X
# Fetched and predicted satellite row 23192 with 204 images along X
# Fetched and predicted satellite row 23193 with 205 images along X
# Fetched and predicted satellite row 23194 with 207 images along X
# Fetched and predicted satellite row 23195 with 208 images along X
# Fetched and predicted satellite row 23196 with 177 images along X
# Fetched and predicted satellite row 23197 with 171 images along X
# Fetched and predicted satellite row 23198 with 167 images along X
# Fetched and predicted satellite row 23199 with 161 images along X
# Fetched and predicted satellite row 23200 with 153 images along X
# Fetched and predicted satellite row 23201 with 149 images along X
# Fetched and predicted satellite row 23202 with 144 images along X
# Fetched and predicted satellite row 23203 with 142 images along X
# Fetched and predicted satellite row 23204 with 140 images along X
# Fetched and predicted satellite row 23205 with 139 images along X
# Fetched and predicted satellite row 23206 with 134 images along X
# Fetched and predicted satellite row 23207 with 124 images along X
# Fetched and predicted satellite row 23208 with 117 images along X
# Fetched and predicted satellite row 23209 with 111 images along X
# Fetched and predicted satellite row 23210 with 106 images along X
# Fetched and predicted satellite row 23211 with 101 images along X
# Fetched and predicted satellite row 23212 with 97 images along X
# Fetched and predicted satellite row 23213 with 95 images along X
# Fetched and predicted satellite row 23214 with 90 images along X
# Fetched and predicted satellite row 23215 with 90 images along X
# Fetched and predicted satellite row 23216 with 84 images along X
# Fetched and predicted satellite row 23217 with 81 images along X
# Fetched and predicted satellite row 23218 with 81 images along X
# C:\Users\serge\Documents\EPFL\Personal Interaction Studio\Code2\imagefunctions.py:19: RuntimeWarning: divide by zero encountered in log
#   alpha * np.log(img[:, :, 2] / float(255)) -
# C:\Users\serge\Documents\EPFL\Personal Interaction Studio\Code2\imagefunctions.py:20: RuntimeWarning: divide by zero encountered in log
#   (1 - alpha) * np.log(img[:, :, 0] / float(255)))
# c:\program files\python36\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\serge\Documents\EPFL\Personal Interaction Studio\Code2\imagefunctions.py:54: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   return features.as_matrix()
# C:\Users\serge\Documents\EPFL\Personal Interaction Studio\Code2\imagefunctions.py:19: RuntimeWarning: invalid value encountered in subtract
#   alpha * np.log(img[:, :, 2] / float(255)) -
# C:\Users\serge\Documents\EPFL\Personal Interaction Studio\Code2\imagefunctions.py:20: RuntimeWarning: invalid value encountered in subtract
#   (1 - alpha) * np.log(img[:, :, 0] / float(255)))
# Fetched and predicted satellite row 23219 with 83 images along X
# Fetched and predicted satellite row 23220 with 82 images along X
# Fetched and predicted satellite row 23221 with 77 images along X
# Fetched and predicted satellite row 23222 with 77 images along X
# Fetched and predicted satellite row 23223 with 77 images along X
# Fetched and predicted satellite row 23224 with 73 images along X
# Fetched and predicted satellite row 23225 with 74 images along X
# Fetched and predicted satellite row 23226 with 75 images along X
# Fetched and predicted satellite row 23227 with 73 images along X
# Fetched and predicted satellite row 23228 with 73 images along X
# Fetched and predicted satellite row 23229 with 73 images along X
# Fetched and predicted satellite row 23230 with 71 images along X
# Fetched and predicted satellite row 23231 with 71 images along X
# Fetched and predicted satellite row 23232 with 69 images along X
# Fetched and predicted satellite row 23233 with 67 images along X
# Fetched and predicted satellite row 23234 with 64 images along X
# Fetched and predicted satellite row 23235 with 63 images along X
# Fetched and predicted satellite row 23236 with 59 images along X
# Fetched and predicted satellite row 23237 with 57 images along X
# Fetched and predicted satellite row 23238 with 53 images along X
# Fetched and predicted satellite row 23239 with 49 images along X
# Fetched and predicted satellite row 23240 with 44 images along X
# Fetched and predicted satellite row 23241 with 42 images along X
# Fetched and predicted satellite row 23242 with 42 images along X
# Fetched and predicted satellite row 23243 with 42 images along X
# Fetched and predicted satellite row 23244 with 42 images along X
# Fetched and predicted satellite row 23245 with 39 images along X
# Fetched and predicted satellite row 23246 with 37 images along X
# Fetched and predicted satellite row 23247 with 36 images along X
# Fetched and predicted satellite row 23248 with 35 images along X
# Fetched and predicted satellite row 23249 with 31 images along X
# Fetched and predicted satellite row 23250 with 30 images along X
# Fetched and predicted satellite row 23251 with 30 images along X
# Fetched and predicted satellite row 23252 with 28 images along X
# Fetched and predicted satellite row 23253 with 53 images along X
# Fetched and predicted satellite row 23254 with 49 images along X
# Fetched and predicted satellite row 23255 with 49 images along X
# Fetched and predicted satellite row 23256 with 49 images along X
# Fetched and predicted satellite row 23257 with 48 images along X
# Fetched and predicted satellite row 23258 with 47 images along X
# Fetched and predicted satellite row 23259 with 45 images along X
# Fetched and predicted satellite row 23260 with 44 images along X
# Fetched and predicted satellite row 23261 with 42 images along X
# Fetched and predicted satellite row 23262 with 40 images along X
# Fetched and predicted satellite row 23263 with 34 images along X
# Fetched and predicted satellite row 23264 with 32 images along X
# Fetched and predicted satellite row 23265 with 30 images along X
# Fetched and predicted satellite row 23266 with 27 images along X

# %%
geojson = json.load(open('Geneva.geojson'))
polygon = utils.polygon_union(geojson['features'])
bounds = polygon.bounds
zoom = 16

# %%
lat, lon = bounds[3], bounds[0]
start_numx, start_numy = utils.deg2num(lat, lon, zoom)
numx, numy = start_numx, start_numy

tile_count = 0
total_tile_count = 0
tile_x_count = 0
tile_y_count = 0
fetcher = MapBoxFetcher()

while lat >= bounds[1]:
    while lon <= bounds[2]:
        c_poly = polygonFromSquareCoordinates(getTileCorners(numx, numy, zoom))
        if polygon.intersects(c_poly):
            total_tile_count += 1
        tile_count += 1

        numx += 1
        lon = utils.num2deg(numx, numy, zoom)[1]
    lon = bounds[0]
    numx = start_numx
    numy += 1
    tile_y_count += 1
    lat = utils.num2deg(numx, numy, zoom)[0]
tile_x_count = tile_count // tile_y_count
    
print('Polygon contains {} tiles at zoom level {} with tile resolution {}x{}'.format(
    total_tile_count,
    zoom,
    tile_y_count,
    tile_x_count
))
# Out:
# Polygon contains 1772 tiles at zoom level 16 with tile resolution 63x65

# %%
zoom = 16
lat, lon = bounds[3], bounds[0]
start_numx, start_numy = utils.deg2num(lat, lon, zoom)
numx, numy = start_numx, start_numy

fetcher = MapBoxFetcher()

data = []

while lat >= bounds[1]:
    read_numxs = []
    added = False
    if os.path.isfile('Data/Predictions-Y{}.p'.format(numy)):
        with open('Data/Predictions-Y{}.p'.format(numy), 'rb') as f:
            data = pickle.load(f)
            for c in data:
                read_numxs.append(c['x'])
    while lon <= bounds[2]:
        if numx in read_numxs:
            numx += 1
            lon = utils.num2deg(numx, numy, zoom)[1]
            continue
        c_poly = polygonFromSquareCoordinates(getTileCorners(numx, numy, zoom))
        if polygon.intersects(c_poly):
            sat_img = fetcher.satellite(numx, numy, zoom, hq=True)
            data.append({
                'x': numx,
                'y': numy,
                'pred': imagefunctions.threshold(imagefunctions.filter(tree_model.predict_proba(sat_img.array())))
            })
            added = True
        numx += 1
        lon = utils.num2deg(numx, numy, zoom)[1]
    if added:
        pickle.dump(data, open('Data/Predictions-Y{}.p'.format(numy), 'wb'))
    print('Fetched and predicted satellite row {} with {} images along X'.format(numy, len(data)))
    data = []
        
    lon = bounds[0]
    numx = start_numx
    numy += 1
    lat = utils.num2deg(numx, numy, zoom)[0]
# Out:
# Fetched and predicted satellite row 23219 with 83 images along X
# Fetched and predicted satellite row 23220 with 82 images along X
# C:\Users\serge\Documents\EPFL\Personal Interaction Studio\Code2\imagefunctions.py:19: RuntimeWarning: divide by zero encountered in log
#   alpha * np.log(img[:, :, 2] / float(255)) -
# C:\Users\serge\Documents\EPFL\Personal Interaction Studio\Code2\imagefunctions.py:20: RuntimeWarning: divide by zero encountered in log
#   (1 - alpha) * np.log(img[:, :, 0] / float(255)))
# c:\program files\python36\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\serge\Documents\EPFL\Personal Interaction Studio\Code2\imagefunctions.py:54: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   return features.as_matrix()
# C:\Users\serge\Documents\EPFL\Personal Interaction Studio\Code2\imagefunctions.py:20: RuntimeWarning: invalid value encountered in subtract
#   (1 - alpha) * np.log(img[:, :, 0] / float(255)))
# Fetched and predicted satellite row 23221 with 81 images along X
# C:\Users\serge\Documents\EPFL\Personal Interaction Studio\Code2\imagefunctions.py:19: RuntimeWarning: invalid value encountered in subtract
#   alpha * np.log(img[:, :, 2] / float(255)) -
# Fetched and predicted satellite row 23222 with 81 images along X
# Fetched and predicted satellite row 23223 with 81 images along X
# Fetched and predicted satellite row 23224 with 79 images along X
# Fetched and predicted satellite row 23225 with 81 images along X
# Fetched and predicted satellite row 23226 with 79 images along X
# Fetched and predicted satellite row 23227 with 74 images along X
# Fetched and predicted satellite row 23228 with 73 images along X
# Fetched and predicted satellite row 23229 with 73 images along X
# Fetched and predicted satellite row 23230 with 71 images along X
# Fetched and predicted satellite row 23231 with 72 images along X
# Fetched and predicted satellite row 23232 with 70 images along X
# Fetched and predicted satellite row 23233 with 69 images along X
# Fetched and predicted satellite row 23234 with 71 images along X
# Fetched and predicted satellite row 23235 with 73 images along X
# Fetched and predicted satellite row 23236 with 71 images along X
# Fetched and predicted satellite row 23237 with 74 images along X
# Fetched and predicted satellite row 23238 with 74 images along X
# Fetched and predicted satellite row 23239 with 74 images along X
# Fetched and predicted satellite row 23240 with 72 images along X
# Fetched and predicted satellite row 23241 with 67 images along X
# Fetched and predicted satellite row 23242 with 67 images along X
# Fetched and predicted satellite row 23243 with 67 images along X
# Fetched and predicted satellite row 23244 with 68 images along X
# Fetched and predicted satellite row 23245 with 66 images along X
# Fetched and predicted satellite row 23246 with 66 images along X
# Fetched and predicted satellite row 23247 with 68 images along X
# Fetched and predicted satellite row 23248 with 68 images along X
# Fetched and predicted satellite row 23249 with 66 images along X
# Fetched and predicted satellite row 23250 with 71 images along X
# Fetched and predicted satellite row 23251 with 76 images along X
# Fetched and predicted satellite row 23252 with 78 images along X
# Fetched and predicted satellite row 23253 with 79 images along X
# Fetched and predicted satellite row 23254 with 77 images along X
# Fetched and predicted satellite row 23255 with 77 images along X
# Fetched and predicted satellite row 23256 with 79 images along X
# Fetched and predicted satellite row 23257 with 77 images along X
# Fetched and predicted satellite row 23258 with 78 images along X
# Fetched and predicted satellite row 23259 with 74 images along X
# Fetched and predicted satellite row 23260 with 72 images along X
# Fetched and predicted satellite row 23261 with 68 images along X
# Fetched and predicted satellite row 23262 with 63 images along X
# Fetched and predicted satellite row 23263 with 56 images along X
# Fetched and predicted satellite row 23264 with 52 images along X
# Fetched and predicted satellite row 23265 with 48 images along X
# Fetched and predicted satellite row 23266 with 43 images along X
# Fetched and predicted satellite row 23267 with 41 images along X
# Fetched and predicted satellite row 23268 with 42 images along X
# Fetched and predicted satellite row 23269 with 44 images along X
# Fetched and predicted satellite row 23270 with 44 images along X
# Fetched and predicted satellite row 23271 with 44 images along X
# Fetched and predicted satellite row 23272 with 45 images along X
# Fetched and predicted satellite row 23273 with 38 images along X
# Fetched and predicted satellite row 23274 with 37 images along X
# Fetched and predicted satellite row 23275 with 36 images along X
# Fetched and predicted satellite row 23276 with 30 images along X
# Fetched and predicted satellite row 23277 with 26 images along X
# Fetched and predicted satellite row 23278 with 15 images along X
# Fetched and predicted satellite row 23279 with 9 images along X
# Fetched and predicted satellite row 23280 with 5 images along X
# Fetched and predicted satellite row 23281 with 3 images along X
